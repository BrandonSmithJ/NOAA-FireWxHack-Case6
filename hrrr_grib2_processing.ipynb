# %% [markdown]
# # Overview
#
# This notebook processes grib2 files with HRRR data.  If you run every code cell in order, this notebook will do the following:
#
# 1. Download one HRRR file (init 2100 UTC 7 Sep 2022, valid 0000 UTC 8 Sep 2022 -- thus a 3-hour forecast).
# 2. Extract needed predictor variables from the HRRR file.
# 3. Save predictor variables to an xarray table and write this xarray table to a NetCDF file.

# %% [markdown]
# # TODO
#
#  - Determine the sentinel value that HRRR files use for missing data.  I have not found any missing data yet.
#  - Stop replying on wgrib2.  There is nothing wrong with wgrib2, but currently the Python code needs to call wgrib2 via `subprocess.call`, which creates a temporary text file that Python then needs to read in.  This is sloppy.  I should use pygrib or something similar, but I have never been able to successfully install pygrib.

# %% [markdown]
# # Install wgrib2
#
# This is ugly, but it works!

# %%
# !wget ftp://ftp.cpc.ncep.noaa.gov/wd51we/wgrib2/wgrib2.tgz
# Out:
# --2022-09-08 22:38:41--  ftp://ftp.cpc.ncep.noaa.gov/wd51we/wgrib2/wgrib2.tgz
#            => ‘wgrib2.tgz’
# Resolving ftp.cpc.ncep.noaa.gov (ftp.cpc.ncep.noaa.gov)... 140.90.101.71
# Connecting to ftp.cpc.ncep.noaa.gov (ftp.cpc.ncep.noaa.gov)|140.90.101.71|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /wd51we/wgrib2 ... done.
# ==> SIZE wgrib2.tgz ... 30034766
# ==> PASV ... done.    ==> RETR wgrib2.tgz ... done.
# Length: 30034766 (29M) (unauthoritative)
#
# wgrib2.tgz          100%[===================>]  28.64M  1.43MB/s    in 26s
#
# 2022-09-08 22:39:11 (1.11 MB/s) - ‘wgrib2.tgz’ saved [30034766]

# %%
import tarfile

tar_file_handle = tarfile.open('wgrib2.tgz')
tar_file_handle.extractall('/content/wgrib2_install')
tar_file_handle.close()

# %%
# !cd /content/wgrib2_install/grib2; export CC=gcc; export FC=gfortran; make
# Out:
# Streaming output truncated to the last 5000 lines.
#  /usr/bin/install -c -m 644 'jasper.h' '/content/wgrib2_install/grib2/include/jasper/jasper.h'
#  /usr/bin/install -c -m 644 'jas_config.h' '/content/wgrib2_install/grib2/include/jasper/jas_config.h'
#  /usr/bin/install -c -m 644 'jas_config2.h' '/content/wgrib2_install/grib2/include/jasper/jas_config2.h'
#  /usr/bin/install -c -m 644 'jas_cm.h' '/content/wgrib2_install/grib2/include/jasper/jas_cm.h'
#  /usr/bin/install -c -m 644 'jas_fix.h' '/content/wgrib2_install/grib2/include/jasper/jas_fix.h'
#  /usr/bin/install -c -m 644 'jas_debug.h' '/content/wgrib2_install/grib2/include/jasper/jas_debug.h'
#  /usr/bin/install -c -m 644 'jas_getopt.h' '/content/wgrib2_install/grib2/include/jasper/jas_getopt.h'
#  /usr/bin/install -c -m 644 'jas_icc.h' '/content/wgrib2_install/grib2/include/jasper/jas_icc.h'
#  /usr/bin/install -c -m 644 'jas_image.h' '/content/wgrib2_install/grib2/include/jasper/jas_image.h'
#  /usr/bin/install -c -m 644 'jas_init.h' '/content/wgrib2_install/grib2/include/jasper/jas_init.h'
#  /usr/bin/install -c -m 644 'jas_malloc.h' '/content/wgrib2_install/grib2/include/jasper/jas_malloc.h'
#  /usr/bin/install -c -m 644 'jas_math.h' '/content/wgrib2_install/grib2/include/jasper/jas_math.h'
#  /usr/bin/install -c -m 644 'jas_seq.h' '/content/wgrib2_install/grib2/include/jasper/jas_seq.h'
#  /usr/bin/install -c -m 644 'jas_stream.h' '/content/wgrib2_install/grib2/include/jasper/jas_stream.h'
#  /usr/bin/install -c -m 644 'jas_string.h' '/content/wgrib2_install/grib2/include/jasper/jas_string.h'
#  /usr/bin/install -c -m 644 'jas_tmr.h' '/content/wgrib2_install/grib2/include/jasper/jas_tmr.h'
#  /usr/bin/install -c -m 644 'jas_tvp.h' '/content/wgrib2_install/grib2/include/jasper/jas_tvp.h'
#  /usr/bin/install -c -m 644 'jas_types.h' '/content/wgrib2_install/grib2/include/jasper/jas_types.h'
#  /usr/bin/install -c -m 644 'jas_version.h' '/content/wgrib2_install/grib2/include/jasper/jas_version.h'
# make[6]: Leaving directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include/jasper'
# make[5]: Leaving directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include/jasper'
# make[5]: Entering directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include'
# make[6]: Entering directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include'
# make[6]: Nothing to be done for 'install-exec-am'.
# make[6]: Nothing to be done for 'install-data-am'.
# make[6]: Leaving directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include'
# make[5]: Leaving directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include'
# make[4]: Leaving directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include'
# Making install in base
# make[4]: Entering directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/base'
# make[5]: Entering directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/base'
# make[5]: Nothing to be done for 'install-exec-am'.
# make[5]: Nothing to be done for 'install-data-am'.
# make[5]: Leaving directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/base'
# make[4]: Leaving directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/base'
# Making install in bmp
# make[4]: Entering directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/bmp'
# make[5]: Entering directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/bmp'
# make[5]: Nothing to be done for 'install-exec-am'.
# make[5]: Nothing to be done for 'install-data-am'.
# make[5]: Leaving directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/bmp'
# make[4]: Leaving directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/bmp'
# Making install in jp2
# make[4]: Entering directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/jp2'
# make[5]: Entering directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/jp2'
# make[5]: Nothing to be done for 'install-exec-am'.
# make[5]: Nothing to be done for 'install-data-am'.
# make[5]: Leaving directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/jp2'
# make[4]: Leaving directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/jp2'
# Making install in jpc
# make[4]: Entering directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/jpc'
# make[5]: Entering directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/jpc'
# make[5]: Nothing to be done for 'install-exec-am'.
# make[5]: Nothing to be done for 'install-data-am'.
# make[5]: Leaving directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/jpc'
# make[4]: Leaving directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/jpc'
# Making install in jpg
# make[4]: Entering directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/jpg'
# make[5]: Entering directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/jpg'
# make[5]: Nothing to be done for 'install-exec-am'.
# make[5]: Nothing to be done for 'install-data-am'.
# make[5]: Leaving directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/jpg'
# make[4]: Leaving directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/jpg'
# Making install in mif
# make[4]: Entering directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/mif'
# make[5]: Entering directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/mif'
# make[5]: Nothing to be done for 'install-exec-am'.
# make[5]: Nothing to be done for 'install-data-am'.
# make[5]: Leaving directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/mif'
# make[4]: Leaving directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/mif'
# Making install in pgx
# make[4]: Entering directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/pgx'
# make[5]: Entering directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/pgx'
# make[5]: Nothing to be done for 'install-exec-am'.
# make[5]: Nothing to be done for 'install-data-am'.
# make[5]: Leaving directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/pgx'
# make[4]: Leaving directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/pgx'
# Making install in pnm
# make[4]: Entering directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/pnm'
# make[5]: Entering directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/pnm'
# make[5]: Nothing to be done for 'install-exec-am'.
# make[5]: Nothing to be done for 'install-data-am'.
# make[5]: Leaving directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/pnm'
# make[4]: Leaving directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/pnm'
# Making install in ras
# make[4]: Entering directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/ras'
# make[5]: Entering directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/ras'
# make[5]: Nothing to be done for 'install-exec-am'.
# make[5]: Nothing to be done for 'install-data-am'.
# make[5]: Leaving directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/ras'
# make[4]: Leaving directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/ras'
# make[4]: Entering directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper'
# make[5]: Entering directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper'
# test -z "/content/wgrib2_install/grib2/lib" || mkdir -p -- "/content/wgrib2_install/grib2/lib"
#  /bin/bash ../../libtool --mode=install /usr/bin/install -c  'libjasper.la' '/content/wgrib2_install/grib2/lib/libjasper.la'
# /usr/bin/install -c .libs/libjasper.lai /content/wgrib2_install/grib2/lib/libjasper.la
# /usr/bin/install -c .libs/libjasper.a /content/wgrib2_install/grib2/lib/libjasper.a
# chmod 644 /content/wgrib2_install/grib2/lib/libjasper.a
# ranlib /content/wgrib2_install/grib2/lib/libjasper.a
# PATH="$PATH:/sbin" ldconfig -n /content/wgrib2_install/grib2/lib
# ----------------------------------------------------------------------
# Libraries have been installed in:
#    /content/wgrib2_install/grib2/lib
#
# If you ever happen to want to link against installed libraries
# in a given directory, LIBDIR, you must either use libtool, and
# specify the full pathname of the library, or use the `-LLIBDIR'
# flag during linking and do at least one of the following:
#    - add LIBDIR to the `LD_LIBRARY_PATH' environment variable
#      during execution
#    - add LIBDIR to the `LD_RUN_PATH' environment variable
#      during linking
#    - use the `-Wl,--rpath -Wl,LIBDIR' linker flag
#    - have your system administrator add LIBDIR to `/etc/ld.so.conf'
#
# See any operating system documentation about shared libraries for
# more information, such as the ld(1) and ld.so(8) manual pages.
# ----------------------------------------------------------------------
# make[5]: Nothing to be done for 'install-data-am'.
# make[5]: Leaving directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper'
# make[4]: Leaving directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper'
# make[3]: Leaving directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper'
# Making install in appl
# make[3]: Entering directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/appl'
# make[4]: Entering directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/appl'
# test -z "/content/wgrib2_install/grib2/bin" || mkdir -p -- "/content/wgrib2_install/grib2/bin"
#   /bin/bash ../../libtool --mode=install /usr/bin/install -c 'jasper' '/content/wgrib2_install/grib2/bin/jasper'
# /usr/bin/install -c jasper /content/wgrib2_install/grib2/bin/jasper
#   /bin/bash ../../libtool --mode=install /usr/bin/install -c 'imgcmp' '/content/wgrib2_install/grib2/bin/imgcmp'
# /usr/bin/install -c imgcmp /content/wgrib2_install/grib2/bin/imgcmp
#   /bin/bash ../../libtool --mode=install /usr/bin/install -c 'imginfo' '/content/wgrib2_install/grib2/bin/imginfo'
# /usr/bin/install -c imginfo /content/wgrib2_install/grib2/bin/imginfo
#   /bin/bash ../../libtool --mode=install /usr/bin/install -c 'tmrdemo' '/content/wgrib2_install/grib2/bin/tmrdemo'
# /usr/bin/install -c tmrdemo /content/wgrib2_install/grib2/bin/tmrdemo
# test -z "/content/wgrib2_install/grib2/man/man1" || mkdir -p -- "/content/wgrib2_install/grib2/man/man1"
#  /usr/bin/install -c -m 644 './imgcmp.1' '/content/wgrib2_install/grib2/man/man1/imgcmp.1'
#  /usr/bin/install -c -m 644 './imginfo.1' '/content/wgrib2_install/grib2/man/man1/imginfo.1'
#  /usr/bin/install -c -m 644 './jasper.1' '/content/wgrib2_install/grib2/man/man1/jasper.1'
#  /usr/bin/install -c -m 644 './jiv.1' '/content/wgrib2_install/grib2/man/man1/jiv.1'
# make[4]: Leaving directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/appl'
# make[3]: Leaving directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/appl'
# Making install in msvc
# make[3]: Entering directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/msvc'
# make[4]: Entering directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/msvc'
# make[4]: Nothing to be done for 'install-exec-am'.
# make[4]: Nothing to be done for 'install-data-am'.
# make[4]: Leaving directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/msvc'
# make[3]: Leaving directory '/content/wgrib2_install/grib2/jasper-1.900.1/src/msvc'
# make[3]: Entering directory '/content/wgrib2_install/grib2/jasper-1.900.1/src'
# make[4]: Entering directory '/content/wgrib2_install/grib2/jasper-1.900.1/src'
# make[4]: Nothing to be done for 'install-exec-am'.
# make[4]: Nothing to be done for 'install-data-am'.
# make[4]: Leaving directory '/content/wgrib2_install/grib2/jasper-1.900.1/src'
# make[3]: Leaving directory '/content/wgrib2_install/grib2/jasper-1.900.1/src'
# make[2]: Leaving directory '/content/wgrib2_install/grib2/jasper-1.900.1/src'
# make[2]: Entering directory '/content/wgrib2_install/grib2/jasper-1.900.1'
# make[3]: Entering directory '/content/wgrib2_install/grib2/jasper-1.900.1'
# make[3]: Nothing to be done for 'install-exec-am'.
# make[3]: Nothing to be done for 'install-data-am'.
# make[3]: Leaving directory '/content/wgrib2_install/grib2/jasper-1.900.1'
# make[2]: Leaving directory '/content/wgrib2_install/grib2/jasper-1.900.1'
# make[1]: Leaving directory '/content/wgrib2_install/grib2/jasper-1.900.1'
# cp libaec-1.0.2.tar.gz tmpaec.tar.gz
# gunzip -n -f tmpaec.tar.gz
# tar -xvf tmpaec.tar
# libaec-1.0.2/
# libaec-1.0.2/configure
# libaec-1.0.2/data/
# libaec-1.0.2/data/typical.rz
# libaec-1.0.2/data/121B2TestData/
# libaec-1.0.2/data/121B2TestData/AllOptions/
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p256n03.dat
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p512n31.rz
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p512n26.dat
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p512n29.rz
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p512n32.rz
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p512n17.rz
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p512n17.dat
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p512n23.rz
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p256n10.dat
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p512n26.rz
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p512n24.rz
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p256n01-basic.rz
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p256n10.rz
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p256n12.rz
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p512n22.rz
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p256n07.dat
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p512n28.dat
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p256n11.dat
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p256n05.rz
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p512n19.rz
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p512n32.dat
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p512n30.dat
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p512n19.dat
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p256n13.dat
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p512n29.dat
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p512n27.rz
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p256n16.rz
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p256n14.dat
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p512n31.dat
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p256n13.rz
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p256n03-basic.rz
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p256n15.rz
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p512n27.dat
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p256n04-basic.rz
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p256n08.rz
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p256n05.dat
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p256n09.rz
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p256n16.dat
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p256n02-restricted.rz
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p512n23.dat
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p256n04.dat
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p256n12.dat
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p256n02-basic.rz
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p512n18.dat
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p512n25.rz
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p256n14.rz
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p512n20.rz
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p256n09.dat
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p256n04-restricted.rz
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p256n07.rz
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p256n06.rz
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p512n21.dat
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p512n18.rz
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p256n02.dat
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p256n01-restricted.rz
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p256n06.dat
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p512n20.dat
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p256n08.dat
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p512n21.rz
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p512n30.rz
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p256n01.dat
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p256n03-restricted.rz
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p256n11.rz
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p512n22.dat
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p512n28.rz
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p512n25.dat
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p512n24.dat
# libaec-1.0.2/data/121B2TestData/AllOptions/test_p256n15.dat
# libaec-1.0.2/data/121B2TestData/README121BTest.docx
# libaec-1.0.2/data/121B2TestData/LowEntropyOptions/
# libaec-1.0.2/data/121B2TestData/LowEntropyOptions/Lowset1_8bit.n02-restricted.rz
# libaec-1.0.2/data/121B2TestData/LowEntropyOptions/Lowset2_8bit.n02-restricted.rz
# libaec-1.0.2/data/121B2TestData/LowEntropyOptions/Lowset3_8bit.n07.rz
# libaec-1.0.2/data/121B2TestData/LowEntropyOptions/Lowset2_8bit.n07.rz
# libaec-1.0.2/data/121B2TestData/LowEntropyOptions/Lowset3_8bit.n01-restricted.rz
# libaec-1.0.2/data/121B2TestData/LowEntropyOptions/Lowset1_8bit.n04-basic.rz
# libaec-1.0.2/data/121B2TestData/LowEntropyOptions/Lowset3_8bit.n08.rz
# libaec-1.0.2/data/121B2TestData/LowEntropyOptions/Lowset3_8bit.n01-basic.rz
# libaec-1.0.2/data/121B2TestData/LowEntropyOptions/Lowset2_8bit.n01-restricted.rz
# libaec-1.0.2/data/121B2TestData/LowEntropyOptions/Lowset3_8bit.n03-restricted.rz
# libaec-1.0.2/data/121B2TestData/LowEntropyOptions/Lowset1_8bit.n03-basic.rz
# libaec-1.0.2/data/121B2TestData/LowEntropyOptions/Lowset3_8bit.n04-restricted.rz
# libaec-1.0.2/data/121B2TestData/LowEntropyOptions/Lowset1_8bit.n05.rz
# libaec-1.0.2/data/121B2TestData/LowEntropyOptions/Lowset2_8bit.dat
# libaec-1.0.2/data/121B2TestData/LowEntropyOptions/Lowset3_8bit.n02-basic.rz
# libaec-1.0.2/data/121B2TestData/LowEntropyOptions/Lowset2_8bit.n06.rz
# libaec-1.0.2/data/121B2TestData/LowEntropyOptions/Lowset1_8bit.n08.rz
# libaec-1.0.2/data/121B2TestData/LowEntropyOptions/Lowset3_8bit.n04-basic.rz
# libaec-1.0.2/data/121B2TestData/LowEntropyOptions/Lowset2_8bit.n01-basic.rz
# libaec-1.0.2/data/121B2TestData/LowEntropyOptions/Lowset1_8bit.n03-restricted.rz
# libaec-1.0.2/data/121B2TestData/LowEntropyOptions/Lowset1_8bit.n01-basic.rz
# libaec-1.0.2/data/121B2TestData/LowEntropyOptions/Lowset1_8bit.n04-restricted.rz
# libaec-1.0.2/data/121B2TestData/LowEntropyOptions/Lowset2_8bit.n02-basic.rz
# libaec-1.0.2/data/121B2TestData/LowEntropyOptions/Lowset3_8bit.dat
# libaec-1.0.2/data/121B2TestData/LowEntropyOptions/Lowset3_8bit.n03-basic.rz
# libaec-1.0.2/data/121B2TestData/LowEntropyOptions/Lowset2_8bit.n08.rz
# libaec-1.0.2/data/121B2TestData/LowEntropyOptions/Lowset1_8bit.dat
# libaec-1.0.2/data/121B2TestData/LowEntropyOptions/Lowset3_8bit.n06.rz
# libaec-1.0.2/data/121B2TestData/LowEntropyOptions/Lowset2_8bit.n03-restricted.rz
# libaec-1.0.2/data/121B2TestData/LowEntropyOptions/Lowset1_8bit.n06.rz
# libaec-1.0.2/data/121B2TestData/LowEntropyOptions/Lowset2_8bit.n03-basic.rz
# libaec-1.0.2/data/121B2TestData/LowEntropyOptions/Lowset1_8bit.n02-basic.rz
# libaec-1.0.2/data/121B2TestData/LowEntropyOptions/Lowset3_8bit.n02-restricted.rz
# libaec-1.0.2/data/121B2TestData/LowEntropyOptions/Lowset1_8bit.n01-restricted.rz
# libaec-1.0.2/data/121B2TestData/LowEntropyOptions/Lowset3_8bit.n05.rz
# libaec-1.0.2/data/121B2TestData/LowEntropyOptions/Lowset2_8bit.n04-restricted.rz
# libaec-1.0.2/data/121B2TestData/LowEntropyOptions/Lowset2_8bit.n04-basic.rz
# libaec-1.0.2/data/121B2TestData/LowEntropyOptions/Lowset2_8bit.n05.rz
# libaec-1.0.2/data/121B2TestData/LowEntropyOptions/Lowset1_8bit.n07.rz
# libaec-1.0.2/data/121B2TestData/ExtendedParameters/
# libaec-1.0.2/data/121B2TestData/ExtendedParameters/sar32bit.j16.r256.rz
# libaec-1.0.2/data/121B2TestData/ExtendedParameters/sar32bit.dat
# libaec-1.0.2/data/121B2TestData/ExtendedParameters/sar32bit.j64.r4096.rz
# libaec-1.0.2/AUTHORS
# libaec-1.0.2/Makefile.am
# libaec-1.0.2/README.md
# libaec-1.0.2/INSTALL
# libaec-1.0.2/cmake/
# libaec-1.0.2/cmake/config.h.in
# libaec-1.0.2/cmake/macros.cmake
# libaec-1.0.2/doc/
# libaec-1.0.2/doc/patent.txt
# libaec-1.0.2/tests/
# libaec-1.0.2/tests/Makefile.am
# libaec-1.0.2/tests/check_code_options.c
# libaec-1.0.2/tests/check_aec.h
# libaec-1.0.2/tests/check_buffer_sizes.c
# libaec-1.0.2/tests/szcomp.sh
# libaec-1.0.2/tests/Makefile.in
# libaec-1.0.2/tests/CMakeLists.txt
# libaec-1.0.2/tests/check_szcomp.c
# libaec-1.0.2/tests/sampledata.sh
# libaec-1.0.2/tests/check_aec.c
# libaec-1.0.2/tests/check_long_fs.c
# libaec-1.0.2/src/
# libaec-1.0.2/src/szlib.h
# libaec-1.0.2/src/Makefile.am
# libaec-1.0.2/src/encode.h
# libaec-1.0.2/src/libaec.h
# libaec-1.0.2/src/aec.1
# libaec-1.0.2/src/decode.h
# libaec-1.0.2/src/utime.c
# libaec-1.0.2/src/decode.c
# libaec-1.0.2/src/bdec.sh
# libaec-1.0.2/src/Makefile.in
# libaec-1.0.2/src/encode_accessors.c
# libaec-1.0.2/src/CMakeLists.txt
# libaec-1.0.2/src/benc.sh
# libaec-1.0.2/src/encode.c
# libaec-1.0.2/src/encode_accessors.h
# libaec-1.0.2/src/sz_compat.c
# libaec-1.0.2/src/aec.c
# libaec-1.0.2/README.SZIP
# libaec-1.0.2/aclocal.m4
# libaec-1.0.2/m4/
# libaec-1.0.2/m4/libtool.m4
# libaec-1.0.2/m4/ltversion.m4
# libaec-1.0.2/m4/lt~obsolete.m4
# libaec-1.0.2/m4/ltsugar.m4
# libaec-1.0.2/m4/ltoptions.m4
# libaec-1.0.2/THANKS
# libaec-1.0.2/Makefile.in
# libaec-1.0.2/config/
# libaec-1.0.2/config/config.h.in
# libaec-1.0.2/config/config.sub
# libaec-1.0.2/config/install-sh
# libaec-1.0.2/config/ltmain.sh
# libaec-1.0.2/config/missing
# libaec-1.0.2/config/depcomp
# libaec-1.0.2/config/config.guess
# libaec-1.0.2/config/compile
# libaec-1.0.2/config/test-driver
# libaec-1.0.2/CMakeLists.txt
# libaec-1.0.2/configure.ac
# libaec-1.0.2/Copyright.txt
# libaec-1.0.2/CHANGELOG.md
# rm tmpaec.tar
# cd "/content/wgrib2_install/grib2/libaec-1.0.2" && export CFLAGS=" -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include " && ./configure --disable-shared --prefix=/content/wgrib2_install/grib2 && make -j 1 check install
# checking build system type... x86_64-pc-linux-gnu
# checking host system type... x86_64-pc-linux-gnu
# checking how to print strings... printf
# checking for gcc... gcc
# checking whether the C compiler works... yes
# checking for C compiler default output file name... a.out
# checking for suffix of executables...
# checking whether we are cross compiling... no
# checking for suffix of object files... o
# checking whether we are using the GNU C compiler... yes
# checking whether gcc accepts -g... yes
# checking for gcc option to accept ISO C89... none needed
# checking whether gcc understands -c and -o together... yes
# checking for a sed that does not truncate output... /bin/sed
# checking for grep that handles long lines and -e... /bin/grep
# checking for egrep... /bin/grep -E
# checking for fgrep... /bin/grep -F
# checking for ld used by gcc... /usr/bin/ld
# checking if the linker (/usr/bin/ld) is GNU ld... yes
# checking for BSD- or MS-compatible name lister (nm)... /usr/bin/nm -B
# checking the name lister (/usr/bin/nm -B) interface... BSD nm
# checking whether ln -s works... yes
# checking the maximum length of command line arguments... 1572864
# checking how to convert x86_64-pc-linux-gnu file names to x86_64-pc-linux-gnu format... func_convert_file_noop
# checking how to convert x86_64-pc-linux-gnu file names to toolchain format... func_convert_file_noop
# checking for /usr/bin/ld option to reload object files... -r
# checking for objdump... objdump
# checking how to recognize dependent libraries... pass_all
# checking for dlltool... no
# checking how to associate runtime and link libraries... printf %s\n
# checking for ar... ar
# checking for archiver @FILE support... @
# checking for strip... strip
# checking for ranlib... ranlib
# checking for gawk... no
# checking for mawk... mawk
# checking command to parse /usr/bin/nm -B output from gcc object... ok
# checking for sysroot... no
# checking for a working dd... /bin/dd
# checking how to truncate binary pipes... /bin/dd bs=4096 count=1
# ./configure: line 5852: /usr/bin/file: No such file or directory
# checking for mt... no
# checking if : is a manifest tool... no
# checking how to run the C preprocessor... gcc -E
# checking for ANSI C header files... yes
# checking for sys/types.h... yes
# checking for sys/stat.h... yes
# checking for stdlib.h... yes
# checking for string.h... yes
# checking for memory.h... yes
# checking for strings.h... yes
# checking for inttypes.h... yes
# checking for stdint.h... yes
# checking for unistd.h... yes
# checking for dlfcn.h... yes
# checking for objdir... .libs
# checking if gcc supports -fno-rtti -fno-exceptions... no
# checking for gcc option to produce PIC... -fPIC -DPIC
# checking if gcc PIC flag -fPIC -DPIC works... yes
# checking if gcc static flag -static works... yes
# checking if gcc supports -c -o file.o... yes
# checking if gcc supports -c -o file.o... (cached) yes
# checking whether the gcc linker (/usr/bin/ld) supports shared libraries... yes
# checking dynamic linker characteristics... GNU/Linux ld.so
# checking how to hardcode library paths into programs... immediate
# checking whether stripping libraries is possible... yes
# checking if libtool supports shared libraries... yes
# checking whether to build shared libraries... no
# checking whether to build static libraries... yes
# ./configure: line 11359: gl_VISIBILITY: command not found
# checking for a BSD-compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# /content/wgrib2_install/grib2/libaec-1.0.2/config/missing: Unknown `--is-lightweight' option
# Try `/content/wgrib2_install/grib2/libaec-1.0.2/config/missing --help' for more information
# configure: WARNING: 'missing' script is too old or missing
# checking for a thread-safe mkdir -p... /bin/mkdir -p
# checking whether make sets $(MAKE)... yes
# checking for style of include used by make... GNU
# checking whether make supports nested variables... yes
# checking dependency style of gcc... gcc3
# checking whether to enable maintainer-specific portions of Makefiles... yes
# checking for gcc option to accept ISO C99... none needed
# checking for ANSI C header files... (cached) yes
# checking whether byte ordering is bigendian... no
# checking for inline... inline
# checking for int64_t... yes
# checking for size_t... yes
# checking for uint32_t... yes
# checking for uint64_t... yes
# checking for uint8_t... yes
# checking for inline... (cached) inline
# checking for C/C++ restrict keyword... __restrict
# checking for memset... yes
# checking for strstr... yes
# checking for snprintf... yes
# checking whether __builtin_clzll is declared... yes
# checking that generated files are newer than configure... done
# configure: creating ./config.status
# config.status: creating Makefile
# config.status: creating src/Makefile
# config.status: creating tests/Makefile
# config.status: creating config/config.h
# config.status: executing libtool commands
# config.status: executing depfiles commands
# make[1]: Entering directory '/content/wgrib2_install/grib2/libaec-1.0.2'
# Making check in src
# make[2]: Entering directory '/content/wgrib2_install/grib2/libaec-1.0.2/src'
# /bin/bash ../libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I../config  -DBUILDING_LIBAEC   -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include  -MT encode.lo -MD -MP -MF .deps/encode.Tpo -c -o encode.lo encode.c
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I../config -DBUILDING_LIBAEC -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include -MT encode.lo -MD -MP -MF .deps/encode.Tpo -c encode.c -o encode.o
# mv -f .deps/encode.Tpo .deps/encode.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I../config  -DBUILDING_LIBAEC   -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include  -MT encode_accessors.lo -MD -MP -MF .deps/encode_accessors.Tpo -c -o encode_accessors.lo encode_accessors.c
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I../config -DBUILDING_LIBAEC -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include -MT encode_accessors.lo -MD -MP -MF .deps/encode_accessors.Tpo -c encode_accessors.c -o encode_accessors.o
# mv -f .deps/encode_accessors.Tpo .deps/encode_accessors.Plo
# /bin/bash ../libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I../config  -DBUILDING_LIBAEC   -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include  -MT decode.lo -MD -MP -MF .deps/decode.Tpo -c -o decode.lo decode.c
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I../config -DBUILDING_LIBAEC -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include -MT decode.lo -MD -MP -MF .deps/decode.Tpo -c decode.c -o decode.o
# mv -f .deps/decode.Tpo .deps/decode.Plo
# /bin/bash ../libtool  --tag=CC   --mode=link gcc  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include  -version-info 0:8:0 -no-undefined  -o libaec.la -rpath /content/wgrib2_install/grib2/lib encode.lo encode_accessors.lo decode.lo
# libtool: link: ar cru .libs/libaec.a  encode.o encode_accessors.o decode.o
# ar: `u' modifier ignored since `D' is the default (see `U')
# libtool: link: ranlib .libs/libaec.a
# libtool: link: ( cd ".libs" && rm -f "libaec.la" && ln -s "../libaec.la" "libaec.la" )
# /bin/bash ../libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I../config  -DBUILDING_LIBAEC   -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include  -MT sz_compat.lo -MD -MP -MF .deps/sz_compat.Tpo -c -o sz_compat.lo sz_compat.c
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I../config -DBUILDING_LIBAEC -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include -MT sz_compat.lo -MD -MP -MF .deps/sz_compat.Tpo -c sz_compat.c -o sz_compat.o
# sz_compat.c:261:6: warning: no previous prototype for ‘SZ_Compress’ [-Wmissing-prototypes]
#  char SZ_Compress() { return SZ_OK; }
#       ^~~~~~~~~~~
# sz_compat.c: In function ‘SZ_Compress’:
# sz_compat.c:261:6: warning: old-style function definition [-Wold-style-definition]
# mv -f .deps/sz_compat.Tpo .deps/sz_compat.Plo
# /bin/bash ../libtool  --tag=CC   --mode=link gcc  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include  -version-info 2:1:0 -no-undefined  -o libsz.la -rpath /content/wgrib2_install/grib2/lib sz_compat.lo libaec.la
# libtool: link: ar cru .libs/libsz.a  sz_compat.o
# ar: `u' modifier ignored since `D' is the default (see `U')
# libtool: link: ranlib .libs/libsz.a
# libtool: link: ( cd ".libs" && rm -f "libsz.la" && ln -s "../libsz.la" "libsz.la" )
# gcc -DHAVE_CONFIG_H -I. -I../config  -DBUILDING_LIBAEC   -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include  -MT aec.o -MD -MP -MF .deps/aec.Tpo -c -o aec.o aec.c
# aec.c:58:5: warning: no previous prototype for ‘get_param’ [-Wmissing-prototypes]
#  int get_param(unsigned int *param, int *iarg, char *argv[])
#      ^~~~~~~~~
# mv -f .deps/aec.Tpo .deps/aec.Po
# /bin/bash ../libtool  --tag=CC   --mode=link gcc  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    -o aec aec.o libaec.la
# libtool: link: gcc -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include -o aec aec.o  ./.libs/libaec.a -fopenmp
# gcc -DHAVE_CONFIG_H -I. -I../config  -DBUILDING_LIBAEC   -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include  -MT utime.o -MD -MP -MF .deps/utime.Tpo -c -o utime.o utime.c
# mv -f .deps/utime.Tpo .deps/utime.Po
# /bin/bash ../libtool  --tag=CC   --mode=link gcc  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    -o utime utime.o
# libtool: link: gcc -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include -o utime utime.o  -fopenmp
# make[2]: Leaving directory '/content/wgrib2_install/grib2/libaec-1.0.2/src'
# Making check in tests
# make[2]: Entering directory '/content/wgrib2_install/grib2/libaec-1.0.2/tests'
# make  libcheck_aec.la check_code_options check_buffer_sizes check_long_fs check_szcomp
# make[3]: Entering directory '/content/wgrib2_install/grib2/libaec-1.0.2/tests'
# /bin/bash ../libtool  --tag=CC   --mode=compile gcc -DHAVE_CONFIG_H -I. -I../config  -I../src   -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include  -MT check_aec.lo -MD -MP -MF .deps/check_aec.Tpo -c -o check_aec.lo check_aec.c
# libtool: compile:  gcc -DHAVE_CONFIG_H -I. -I../config -I../src -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include -MT check_aec.lo -MD -MP -MF .deps/check_aec.Tpo -c check_aec.c -o check_aec.o
# mv -f .deps/check_aec.Tpo .deps/check_aec.Plo
# /bin/bash ../libtool  --tag=CC   --mode=link gcc  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    -o libcheck_aec.la  check_aec.lo
# libtool: link: ar cru .libs/libcheck_aec.a  check_aec.o
# ar: `u' modifier ignored since `D' is the default (see `U')
# libtool: link: ranlib .libs/libcheck_aec.a
# libtool: link: ( cd ".libs" && rm -f "libcheck_aec.la" && ln -s "../libcheck_aec.la" "libcheck_aec.la" )
# gcc -DHAVE_CONFIG_H -I. -I../config  -I../src   -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include  -MT check_code_options.o -MD -MP -MF .deps/check_code_options.Tpo -c -o check_code_options.o check_code_options.c
# check_code_options.c:8:5: warning: no previous prototype for ‘check_block_sizes’ [-Wmissing-prototypes]
#  int check_block_sizes(struct test_state *state, int id, int id_len)
#      ^~~~~~~~~~~~~~~~~
# check_code_options.c:38:5: warning: no previous prototype for ‘check_zero’ [-Wmissing-prototypes]
#  int check_zero(struct test_state *state)
#      ^~~~~~~~~~
# check_code_options.c:56:5: warning: no previous prototype for ‘check_splitting’ [-Wmissing-prototypes]
#  int check_splitting(struct test_state *state, int k)
#      ^~~~~~~~~~~~~~~
# check_code_options.c:93:5: warning: no previous prototype for ‘check_uncompressed’ [-Wmissing-prototypes]
#  int check_uncompressed(struct test_state *state)
#      ^~~~~~~~~~~~~~~~~~
# check_code_options.c:118:5: warning: no previous prototype for ‘check_fs’ [-Wmissing-prototypes]
#  int check_fs(struct test_state *state)
#      ^~~~~~~~
# check_code_options.c:154:5: warning: no previous prototype for ‘check_se’ [-Wmissing-prototypes]
#  int check_se(struct test_state *state)
#      ^~~~~~~~
# check_code_options.c:198:5: warning: no previous prototype for ‘check_bps’ [-Wmissing-prototypes]
#  int check_bps(struct test_state *state)
#      ^~~~~~~~~
# check_code_options.c:237:5: warning: no previous prototype for ‘check_byte_orderings’ [-Wmissing-prototypes]
#  int check_byte_orderings(struct test_state *state)
#      ^~~~~~~~~~~~~~~~~~~~
# mv -f .deps/check_code_options.Tpo .deps/check_code_options.Po
# /bin/bash ../libtool  --tag=CC   --mode=link gcc  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    -o check_code_options check_code_options.o libcheck_aec.la ../src/libaec.la
# libtool: link: gcc -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include -o check_code_options check_code_options.o  ./.libs/libcheck_aec.a ../src/.libs/libaec.a -fopenmp
# gcc -DHAVE_CONFIG_H -I. -I../config  -I../src   -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include  -MT check_buffer_sizes.o -MD -MP -MF .deps/check_buffer_sizes.Tpo -c -o check_buffer_sizes.o check_buffer_sizes.c
# check_buffer_sizes.c:8:5: warning: no previous prototype for ‘check_block_sizes’ [-Wmissing-prototypes]
#  int check_block_sizes(struct test_state *state)
#      ^~~~~~~~~~~~~~~~~
# check_buffer_sizes.c:23:5: warning: no previous prototype for ‘check_block_sizes_short’ [-Wmissing-prototypes]
#  int check_block_sizes_short(struct test_state *state)
#      ^~~~~~~~~~~~~~~~~~~~~~~
# check_buffer_sizes.c:46:5: warning: no previous prototype for ‘check_rsi’ [-Wmissing-prototypes]
#  int check_rsi(struct test_state *state)
#      ^~~~~~~~~
# mv -f .deps/check_buffer_sizes.Tpo .deps/check_buffer_sizes.Po
# /bin/bash ../libtool  --tag=CC   --mode=link gcc  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    -o check_buffer_sizes check_buffer_sizes.o libcheck_aec.la ../src/libaec.la
# libtool: link: gcc -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include -o check_buffer_sizes check_buffer_sizes.o  ./.libs/libcheck_aec.a ../src/.libs/libaec.a -fopenmp
# gcc -DHAVE_CONFIG_H -I. -I../config  -I../src   -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include  -MT check_long_fs.o -MD -MP -MF .deps/check_long_fs.Tpo -c -o check_long_fs.o check_long_fs.c
# check_long_fs.c:8:5: warning: no previous prototype for ‘check_long_fs’ [-Wmissing-prototypes]
#  int check_long_fs(struct test_state *state)
#      ^~~~~~~~~~~~~
# mv -f .deps/check_long_fs.Tpo .deps/check_long_fs.Po
# /bin/bash ../libtool  --tag=CC   --mode=link gcc  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    -o check_long_fs check_long_fs.o libcheck_aec.la ../src/libaec.la
# libtool: link: gcc -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include -o check_long_fs check_long_fs.o  ./.libs/libcheck_aec.a ../src/.libs/libaec.a -fopenmp
# gcc -DHAVE_CONFIG_H -I. -I../config  -I../src   -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include  -MT check_szcomp.o -MD -MP -MF .deps/check_szcomp.Tpo -c -o check_szcomp.o check_szcomp.c
# mv -f .deps/check_szcomp.Tpo .deps/check_szcomp.Po
# /bin/bash ../libtool  --tag=CC   --mode=link gcc  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    -o check_szcomp check_szcomp.o ../src/libsz.la
# libtool: link: gcc -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include -o check_szcomp check_szcomp.o  ../src/.libs/libsz.a /content/wgrib2_install/grib2/libaec-1.0.2/src/.libs/libaec.a -fopenmp
# make[3]: Leaving directory '/content/wgrib2_install/grib2/libaec-1.0.2/tests'
# make  check-TESTS
# make[3]: Entering directory '/content/wgrib2_install/grib2/libaec-1.0.2/tests'
# make[4]: Entering directory '/content/wgrib2_install/grib2/libaec-1.0.2/tests'
# PASS: check_code_options
# PASS: check_buffer_sizes
# PASS: check_long_fs
# PASS: sampledata.sh
# PASS: szcomp.sh
# ============================================================================
# Testsuite summary for libaec 1.0.2
# ============================================================================
# # TOTAL: 5
# # PASS:  5
# # SKIP:  0
# # XFAIL: 0
# # FAIL:  0
# # XPASS: 0
# # ERROR: 0
# ============================================================================
# make[4]: Leaving directory '/content/wgrib2_install/grib2/libaec-1.0.2/tests'
# make[3]: Leaving directory '/content/wgrib2_install/grib2/libaec-1.0.2/tests'
# make[2]: Leaving directory '/content/wgrib2_install/grib2/libaec-1.0.2/tests'
# make[2]: Entering directory '/content/wgrib2_install/grib2/libaec-1.0.2'
# make[2]: Nothing to be done for 'check-am'.
# make[2]: Leaving directory '/content/wgrib2_install/grib2/libaec-1.0.2'
# Making install in src
# make[2]: Entering directory '/content/wgrib2_install/grib2/libaec-1.0.2/src'
# make[3]: Entering directory '/content/wgrib2_install/grib2/libaec-1.0.2/src'
#  /bin/mkdir -p '/content/wgrib2_install/grib2/lib'
#  /bin/bash ../libtool   --mode=install /usr/bin/install -c   libaec.la libsz.la '/content/wgrib2_install/grib2/lib'
# libtool: install: /usr/bin/install -c .libs/libaec.lai /content/wgrib2_install/grib2/lib/libaec.la
# libtool: install: /usr/bin/install -c .libs/libsz.lai /content/wgrib2_install/grib2/lib/libsz.la
# libtool: install: /usr/bin/install -c .libs/libaec.a /content/wgrib2_install/grib2/lib/libaec.a
# libtool: install: chmod 644 /content/wgrib2_install/grib2/lib/libaec.a
# libtool: install: ranlib /content/wgrib2_install/grib2/lib/libaec.a
# libtool: install: /usr/bin/install -c .libs/libsz.a /content/wgrib2_install/grib2/lib/libsz.a
# libtool: install: chmod 644 /content/wgrib2_install/grib2/lib/libsz.a
# libtool: install: ranlib /content/wgrib2_install/grib2/lib/libsz.a
# libtool: finish: PATH="/opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin:/sbin" ldconfig -n /content/wgrib2_install/grib2/lib
# ----------------------------------------------------------------------
# Libraries have been installed in:
#    /content/wgrib2_install/grib2/lib
#
# If you ever happen to want to link against installed libraries
# in a given directory, LIBDIR, you must either use libtool, and
# specify the full pathname of the library, or use the '-LLIBDIR'
# flag during linking and do at least one of the following:
#    - add LIBDIR to the 'LD_LIBRARY_PATH' environment variable
#      during execution
#    - add LIBDIR to the 'LD_RUN_PATH' environment variable
#      during linking
#    - use the '-Wl,-rpath -Wl,LIBDIR' linker flag
#    - have your system administrator add LIBDIR to '/etc/ld.so.conf'
#
# See any operating system documentation about shared libraries for
# more information, such as the ld(1) and ld.so(8) manual pages.
# ----------------------------------------------------------------------
#  /bin/mkdir -p '/content/wgrib2_install/grib2/bin'
#   /bin/bash ../libtool   --mode=install /usr/bin/install -c aec '/content/wgrib2_install/grib2/bin'
# libtool: install: /usr/bin/install -c aec /content/wgrib2_install/grib2/bin/aec
#  /bin/mkdir -p '/content/wgrib2_install/grib2/include'
#  /usr/bin/install -c -m 644 libaec.h szlib.h '/content/wgrib2_install/grib2/include'
#  /bin/mkdir -p '/content/wgrib2_install/grib2/share/man/man1'
#  /usr/bin/install -c -m 644 aec.1 '/content/wgrib2_install/grib2/share/man/man1'
# make[3]: Leaving directory '/content/wgrib2_install/grib2/libaec-1.0.2/src'
# make[2]: Leaving directory '/content/wgrib2_install/grib2/libaec-1.0.2/src'
# Making install in tests
# make[2]: Entering directory '/content/wgrib2_install/grib2/libaec-1.0.2/tests'
# make[3]: Entering directory '/content/wgrib2_install/grib2/libaec-1.0.2/tests'
# make[3]: Nothing to be done for 'install-exec-am'.
# make[3]: Nothing to be done for 'install-data-am'.
# make[3]: Leaving directory '/content/wgrib2_install/grib2/libaec-1.0.2/tests'
# make[2]: Leaving directory '/content/wgrib2_install/grib2/libaec-1.0.2/tests'
# make[2]: Entering directory '/content/wgrib2_install/grib2/libaec-1.0.2'
# make[3]: Entering directory '/content/wgrib2_install/grib2/libaec-1.0.2'
# make[3]: Nothing to be done for 'install-exec-am'.
# make[3]: Nothing to be done for 'install-data-am'.
# make[3]: Leaving directory '/content/wgrib2_install/grib2/libaec-1.0.2'
# make[2]: Leaving directory '/content/wgrib2_install/grib2/libaec-1.0.2'
# make[1]: Leaving directory '/content/wgrib2_install/grib2/libaec-1.0.2'
# cp netcdf-3.6.3.tar.gz tmpn.tar.gz
# gunzip -f tmpn.tar.gz
# tar -xvf tmpn.tar
# netcdf-3.6.3/
# netcdf-3.6.3/nc_test4/
# netcdf-3.6.3/nc_test4/tst_large.c
# netcdf-3.6.3/nc_test4/bm_file.c
# netcdf-3.6.3/nc_test4/Makefile.in
# netcdf-3.6.3/nc_test4/Makefile.am
# netcdf-3.6.3/nc_test4/cdm_sea_soundings.c
# netcdf-3.6.3/nc_test4/tst_parallel.c
# netcdf-3.6.3/nc_test4/tests.h
# netcdf-3.6.3/nc_test4/tst_create_files.c
# netcdf-3.6.3/nc_test4/tst_parallel3.c
# netcdf-3.6.3/missing
# netcdf-3.6.3/ncgen/
# netcdf-3.6.3/ncgen/run_tests.sh
# netcdf-3.6.3/ncgen/ncgen.l
# netcdf-3.6.3/ncgen/init.c
# netcdf-3.6.3/ncgen/Makefile.in
# netcdf-3.6.3/ncgen/genlib.c
# netcdf-3.6.3/ncgen/Makefile.am
# netcdf-3.6.3/ncgen/genlib.h
# netcdf-3.6.3/ncgen/ncgen.h
# netcdf-3.6.3/ncgen/generic.h
# netcdf-3.6.3/ncgen/ncgentab.h
# netcdf-3.6.3/ncgen/c0.cdl
# netcdf-3.6.3/ncgen/ncgenyy.c
# netcdf-3.6.3/ncgen/escapes.c
# netcdf-3.6.3/ncgen/getfill.c
# netcdf-3.6.3/ncgen/load.c
# netcdf-3.6.3/ncgen/main.c
# netcdf-3.6.3/ncgen/ncgen.1
# netcdf-3.6.3/ncgen/run_nc4_tests.sh
# netcdf-3.6.3/ncgen/ncgentab.c
# netcdf-3.6.3/configure.ac
# netcdf-3.6.3/Makefile.in
# netcdf-3.6.3/nc_test/
# netcdf-3.6.3/nc_test/tst_large.c
# ...
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    Lola.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    Waves.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    VerfTime.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    Ncpu.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    Fix_ncep_4.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    decenc_openjpeg.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    Last.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include   gribtab.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    unpk_0.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    string2time_unit.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    Ftime1.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    End.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    v1_v2_if.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    parse_loop.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    Model_version_date.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    Flush.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    PyInv.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    Level.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    Spectral_bands.c
# Spectral_bands.c: In function ‘f_spectral_bands_extname’:
# Spectral_bands.c:24:17: warning: variable ‘classification’ set but not used [-Wunused-but-set-variable]
#      const char *classification=NULL;
#                  ^~~~~~~~~~~~~~
# Spectral_bands.c:22:63: warning: variable ‘longname’ set but not used [-Wunused-but-set-variable]
#      const char *agency=NULL, *instype=NULL, *shortname=NULL, *longname=NULL;
#                                                                ^~~~~~~~
# Spectral_bands.c:22:17: warning: variable ‘agency’ set but not used [-Wunused-but-set-variable]
#      const char *agency=NULL, *instype=NULL, *shortname=NULL, *longname=NULL;
#                  ^~~~~~
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    grid_ident.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    Set_val.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    Earth.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    Mysql_speed.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    Set_gds.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    addtime.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    ieee2flt_nan.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    openmp_util.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    Bbox.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    mk_gdt.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    Set_ftime2.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    pdt_len.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    rd_seq_grib.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    Ftime.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    Ave_test.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    Set_date.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    space_view2ij.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    Reset_delayed_error.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    subtime.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    Wrt_grib.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    setup_user_gribtable.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    New_grid.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    Sec0.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    Grib_out_irr.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    Sec6.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    missing.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    Alias.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    Csv_long.c
# gcc -c  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include    Cyclic.c
# gcc -o wgrib2  -I/content/wgrib2_install/grib2/include -Wall -Wmissing-prototypes -Wold-style-definition -Werror=format-security -ffast-math -O3 -DGFORTRAN -fopenmp -I/content/wgrib2_install/grib2/jasper-1.900.1/src/libjasper/include   ieee_pk.o Summary.o CubeFace2global.o Fix_CFSv2_fcst.o Grib.o Fix_ncep_2.o GDT.o Mysql.o Netcdf_sup.o Precision.o Latlon.o Set_metadata.o itoshort_a.o Sec3.o Fi.o NCEP_norm.o cubed_sphere2ll.o Tosubmsg.o Inv.o Else.o Limit.o File.o Set_ensm_derived_fcst.o Set_prob.o JMA.o Import.o Range.o Grid_def.o cname.o fnlist.o rotll.o Wind_dir.o Mem_buffer.o copy.o unpk.o Cluster.o bitstream.o Import_grib.o ieee2flt.o update_sec3.o Undefine.o Gribtable_used.o rd_inventory.o Alarm.o Grib_out_irr2.o unpk_complex.o RPN.o Status.o Set_pdt.o Sec1.o simple_pk.o AAIGlong.o wgrib2.o Sec4.o Wind_uv.o Hybrid.o enc_jpeg2000_clone.o Set_byte.o Match_fs.o Ndate.o Fcst_ave.o NCEP_uv.o units.o Fix_ncep_3.o geo.o sec3_grids.o flt2ieee_nan.o lat2ij.o manage_inv_out.o Set_ens_num.o dec_png_clone.o For.o Irr_grids.o flt2ieee.o Ens_qc.o Warn_old_g2lib.o Mod_grib.o int8.o Inv_no.o Config.o Grid_id.o Import_netcdf.o Endif.o Small_grib.o UDF.o Ftime2.o swap_buffer.o Submsg_uv.o Unmerge_fcst.o Fix_undef.o SpatialProcessing.o wxtext.o Ftn_api.o Scaling_0001.o Tigge.o ncep_grids.o Netcdf.o Check_pdt_size.o FlagTable.o ffopen.o Gridout.o Set_percentile.o CodeTable.o stagger.o Set_sec_size.o wgrib2_api.o Names.o Merge.o Ndates.o Scan.o wrtieee.o test_sec.o Time_processing.o EOF.o Unix_time_old.o Proj4.o complex_pk.o Gctpc.o Match.o jpeg_pk.o intpower.o Match_inv.o If_delayed_error.o Set_ts_dates.o proj4_initialize.o Import_grib_fs.o parse_msg.o Wind_speed.o Set_ftime1.o fatal_error.o rdieee_file.o space_view.o Fix_ncep.o Timer.o new_grid_lambertc.o Ave_var.o Geolocation.o Aerosol.o New_grid_order.o Ens_processing.o ExtName.o If_rec.o Export_lonlat.o update_sec4.o unpk_run_length.o read_latlon.o Data.o mk_kgds.o init.o gctpc_ll2xy.o Sec_len.o Reduced_gaussian_grid.o Ensemble.o Csv.o AAIG.o get_unixtime.o crc32.o Box_ave.o Prob.o Help.o Misc.o Grads.o Unix_time.o gaussian2ij.o proj4_transform.o Macro.o Dump.o Write_sec.o Code_Values.o Import_lonlat.o Cress_lola.o Sec5.o aec_pk.o Checksum.o save_string.o Mysql_dump.o codetable_4_230.o Lola.o Waves.o VerfTime.o Ncpu.o Fix_ncep_4.o decenc_openjpeg.o Last.o gribtab.o unpk_0.o string2time_unit.o Ftime1.o End.o v1_v2_if.o parse_loop.o Model_version_date.o Flush.o PyInv.o Level.o Spectral_bands.o grid_ident.o Set_val.o Earth.o Mysql_speed.o Set_gds.o addtime.o ieee2flt_nan.o openmp_util.o Bbox.o mk_gdt.o Set_ftime2.o pdt_len.o rd_seq_grib.o Ftime.o Ave_test.o Set_date.o space_view2ij.o Reset_delayed_error.o subtime.o Wrt_grib.o setup_user_gribtable.o New_grid.o Sec0.o Grib_out_irr.o Sec6.o missing.o Alias.o Csv_long.o Cyclic.o -L/content/wgrib2_install/grib2/lib -lip2_d -lgfortran -lgeo -ljasper -laec -lsp_v2.0.2_d -lnetcdf -lpng12 -lz -lm
# rm Config.o
# make[1]: Leaving directory '/content/wgrib2_install/grib2/wgrib2'
# cd aux_progs && make -f gmerge.make
# make[1]: Entering directory '/content/wgrib2_install/grib2/aux_progs'
# gcc  -o gmerge gmerge.c uint8.c
# make[1]: Leaving directory '/content/wgrib2_install/grib2/aux_progs'
# cd aux_progs && make -f smallest_grib2.make
# make[1]: Entering directory '/content/wgrib2_install/grib2/aux_progs'
# gcc  -o smallest_grib2 smallest_grib2.c uint8.c
# make[1]: Leaving directory '/content/wgrib2_install/grib2/aux_progs'
# cd aux_progs && make -f smallest_4.make
# make[1]: Entering directory '/content/wgrib2_install/grib2/aux_progs'
# gcc  -o smallest_4 smallest_4.c uint8.c
# make[1]: Leaving directory '/content/wgrib2_install/grib2/aux_progs'

# %%
# !chmod +x /content/wgrib2_install/grib2/wgrib2/wgrib2

# %% [markdown]
# # Download HRRR data

# %%
import tarfile
from urllib.request import urlretrieve

TAR_FILE_NAME_ONLINE = (
    'https://storage.googleapis.com/hrrr-grib2-processing-for-fire-wx/'
    'hrrr_data_for_notebook.tar'
)
TAR_FILE_NAME = '/content/hrrr_data_for_notebook.tar'
DATA_DIR_NAME = '/content/hrrr_data_for_notebook'

print('Downloading file: "{0:s}"...'.format(TAR_FILE_NAME_ONLINE))
urlretrieve(TAR_FILE_NAME_ONLINE, TAR_FILE_NAME)

tar_file_handle = tarfile.open(TAR_FILE_NAME)
tar_file_handle.extractall(DATA_DIR_NAME)
tar_file_handle.close()
# Out:
# Downloading file: "https://storage.googleapis.com/hrrr-grib2-processing-for-fire-wx/hrrr_data_for_notebook.tar"...

# %% [markdown]
# # Define constants and import libraries

# %%
import os
import time
import calendar
import tempfile
import warnings
import subprocess
import numpy
import xarray

WGRIB2_EXE_NAME_DEFAULT = '/content/wgrib2_install/grib2/wgrib2/wgrib2'

KILOGRAMS_TO_MICROGRAMS = 1e6

LATITUDE_KEY_ORIG = 'latitude'
LONGITUDE_KEY_ORIG = 'longitude'
VARIABLE_NAMES_3D_ORIG = ['HGT', 'UGRD', 'VGRD', 'VVEL', 'TMP', 'SPFH']
VARIABLE_NAMES_2D_ORIG = ['HPBL', 'MASSDEN', 'COLMD']

ROW_DIMENSION = 'row'
COLUMN_DIMENSION = 'column'
PRESSURE_DIMENSION = 'pressure_mb'

LATITUDE_KEY = 'latitude_deg_n'
LONGITUDE_KEY = 'longitude_deg_e'
FORECAST_TIME_KEY = 'forecast_time_unix_sec'
VALID_TIME_KEY = 'valid_time_unix_sec'

# PRESSURE_LEVELS_MB = numpy.linspace(50, 1000, num=39, dtype=int)
PRESSURE_LEVELS_MB = numpy.array([700, 850, 1000], dtype=int)

VARIABLE_NAMES_3D = [
    'geopotential_height_m_asl', 'zonal_wind_m_s01', 'meridional_wind_m_s01',
    'vertical_velocity_pa_s01', 'temperature_kelvins',
    'specific_humidity_kg_kg01'
]
VARIABLE_NAMES_2D = [
    'boundary_layer_height_m_asl', 'smoke_density_8magl_micrograms_m03',
    'smoke_density_total_column_micrograms_m03'
]
CONVERSION_RATES_2D = numpy.array([
    1, KILOGRAMS_TO_MICROGRAMS, KILOGRAMS_TO_MICROGRAMS
])

# %% [markdown]
# # Define helper methods

# %%
def string_to_unix_sec(time_string, time_directive):
    """Converts time from string to Unix format.

    Unix format = seconds since 0000 UTC 1 Jan 1970.

    :param time_string: Time string.
    :param time_directive: Format of time string (examples: "%Y%m%d" if string
        is "yyyymmdd", "%Y-%m-%d-%H%M%S" if string is "yyyy-mm-dd-HHMMSS",
        etc.).
    :return: unix_time_sec: Time in Unix format.
    """

    time_string = str(time_string)
    time_directive = str(time_directive)

    return calendar.timegm(time.strptime(time_string, time_directive))


def unix_sec_to_string(unix_time_sec, time_directive):
    """Converts time from Unix format to string.

    Unix format = seconds since 0000 UTC 1 Jan 1970.

    :param unix_time_sec: Time in Unix format.
    :param time_directive: Format of time string (examples: "%Y%m%d" if string
        is "yyyymmdd", "%Y-%m-%d-%H%M%S" if string is "yyyy-mm-dd-HHMMSS",
        etc.).
    :return: time_string: Time string.
    """

    unix_time_sec = int(numpy.round(unix_time_sec))
    time_directive = str(time_directive)

    return time.strftime(time_directive, time.gmtime(unix_time_sec))


def read_model_coords(hdf5_file_name):
    """Reads model coordinates from HDF5 file.

    M = number of rows in grid
    N = number of columns in grid

    :param hdf5_file_name: Path to input file.
    :return: latitude_matrix_deg_n: M-by-N numpy array of latitudes (deg north).
    :return: longitude_matrix_deg_e: M-by-N numpy array of longitudes (deg
        east).
    """

    coord_table_xarray = xarray.open_dataset(hdf5_file_name)
    return (
        coord_table_xarray[LATITUDE_KEY_ORIG].values,
        coord_table_xarray[LONGITUDE_KEY_ORIG].values
    )


def read_field_from_grib2(
        grib2_file_name, field_name, num_grid_rows, num_grid_columns,
        wgrib2_exe_name=WGRIB2_EXE_NAME_DEFAULT, raise_error_if_fails=True):
    """Reads one field from grib2 file.

    One field = one variable at one vertical level at one time step

    M = number of rows in grid
    N = number of columns in grid

    :param grib2_file_name: Path to input file.
    :param field_name: Name of field to extract.  For example, 500-mb height is
        "HGT:500 mb".
    :param num_grid_rows: Number of rows in grid.
    :param num_grid_columns: Number of columns in grid.
    :param wgrib2_exe_name: Path to wgrib2 executable on local machine.
        (Sorry, I've never managed to successfully install pygrib or any other
        Python tool for processing grib files, so my hack solution is to call
        wgrib2 outside of Python.)
    :param raise_error_if_fails: Boolean flag.  If True and this method fails,
        will raise an error.  If False and this method fails, the method will
        return None.
    :return: data_matrix: M-by-N numpy array of actual data (yay!)
    :raises: ValueError: if this method fails and
        `raise_error_if_fails == True`.
    """

    # Check input args.
    num_grid_rows = int(numpy.round(num_grid_rows))
    num_grid_columns = int(numpy.round(num_grid_columns))
    field_name = str(field_name)
    wgrib2_exe_name = str(wgrib2_exe_name)
    raise_error_if_fails = bool(raise_error_if_fails)

    assert num_grid_rows > 0
    assert num_grid_columns > 0

    # Extract field from grib2 file to text file.
    temporary_file_name = tempfile.NamedTemporaryFile(
        dir=None, delete=False
    ).name

    command_string = (
        '"{0:s}" "{1:s}" -s | grep -w "{2:s}" | "{0:s}" -i "{1:s}" '
        '-no_header -text "{3:s}"'
    ).format(
        wgrib2_exe_name, grib2_file_name, field_name, temporary_file_name
    )

    print(command_string)

    try:
        subprocess.call(command_string, shell=True)
    except OSError as this_exception:
        os.remove(temporary_file_name)
        if raise_error_if_fails:
            raise

        warning_string = (
            '\n{0:s}\nCommand (shown above) failed (details shown below).'
            '\n{1:s}'
        ).format(
            command_string, str(this_exception)
        )

        warnings.warn(warning_string)
        return None

    # Load field into Python and reshape.
    data_values_1d = numpy.loadtxt(temporary_file_name)
    os.remove(temporary_file_name)

    try:
        data_matrix = numpy.reshape(
            data_values_1d, (num_grid_rows, num_grid_columns)
        )
    except ValueError as this_exception:
        if raise_error_if_fails:
            raise

        warning_string = (
            '\nnumpy.reshape failed (details shown below).\n{0:s}'
        ).format(
            str(this_exception)
        )

        warnings.warn(warning_string)
        return None

    return data_matrix

# %% [markdown]
# # Process data
#
# The next cell processes data (namely, extracts predictor fields and saves them to an xarray table and then a NetCDF file) for the HRRR initialized at 2100 UTC 7 Sep 2022 and valid at 0000 UTC 8 Sep 2022 (a 3-hour forecast).

# %%
MODEL_COORD_FILE_NAME = '/content/hrrr_data_for_notebook/HRRR_latlon.h5'
GRIB2_FILE_NAME = '/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2'
FORECAST_TIME_STRING = '2022-09-07-21'
VALID_TIME_STRING = '2022-09-08-00'

OUTPUT_FILE_NAME = (
    '/content/hrrr_data_for_notebook/hrrr_init={0:s}_valid={1:s}.nc'.format(
        FORECAST_TIME_STRING, VALID_TIME_STRING
    )
)

forecast_time_unix_sec = string_to_unix_sec(FORECAST_TIME_STRING, '%Y-%m-%d-%H')
valid_time_unix_sec = string_to_unix_sec(VALID_TIME_STRING, '%Y-%m-%d-%H')
attribute_dict = {
    FORECAST_TIME_KEY: forecast_time_unix_sec,
    VALID_TIME_KEY: valid_time_unix_sec
}

latitude_matrix_deg_n, longitude_matrix_deg_e = read_model_coords(
    MODEL_COORD_FILE_NAME
)
num_grid_rows = latitude_matrix_deg_n.shape[0]
num_grid_columns = latitude_matrix_deg_n.shape[1]

coord_dict = {
    ROW_DIMENSION: numpy.linspace(
        0, num_grid_rows - 1, num=num_grid_rows, dtype=int
    ),
    COLUMN_DIMENSION: numpy.linspace(
        0, num_grid_columns - 1, num=num_grid_columns, dtype=int
    ),
    PRESSURE_DIMENSION: PRESSURE_LEVELS_MB
}

main_data_dict = {
    LATITUDE_KEY: ((ROW_DIMENSION, COLUMN_DIMENSION), latitude_matrix_deg_n),
    LONGITUDE_KEY: ((ROW_DIMENSION, COLUMN_DIMENSION), longitude_matrix_deg_e)
}

num_pressure_levels = len(PRESSURE_LEVELS_MB)
num_3d_variables = len(VARIABLE_NAMES_3D)

for j in range(num_3d_variables):
    this_data_matrix = numpy.full(
        (num_grid_rows, num_grid_columns, num_pressure_levels), numpy.nan
    )
    
    for i in range(num_pressure_levels):
        this_field_name = '{0:s}:{1:d} mb'.format(
            VARIABLE_NAMES_3D_ORIG[j], PRESSURE_LEVELS_MB[i]
        )

        this_data_matrix[..., i] = read_field_from_grib2(
            grib2_file_name=GRIB2_FILE_NAME, field_name=this_field_name,
            num_grid_rows=num_grid_rows, num_grid_columns=num_grid_columns
        )

    print('Min and max values for {0:s} = {1:.2g}, {2:.2g}'.format(
        VARIABLE_NAMES_3D[j],
        numpy.min(this_data_matrix),
        numpy.max(this_data_matrix)
    ))

    main_data_dict[VARIABLE_NAMES_3D[j]] = (
        (ROW_DIMENSION, COLUMN_DIMENSION, PRESSURE_DIMENSION),
        this_data_matrix
    )

num_2d_variables = len(VARIABLE_NAMES_2D)

for j in range(num_2d_variables):
    this_data_matrix = read_field_from_grib2(
        grib2_file_name=GRIB2_FILE_NAME, field_name=VARIABLE_NAMES_2D_ORIG[j],
        num_grid_rows=num_grid_rows, num_grid_columns=num_grid_columns
    )

    this_data_matrix *= CONVERSION_RATES_2D[j]

    print('Min and max values for {0:s} = {1:.2g}, {2:.2g}'.format(
        VARIABLE_NAMES_2D[j],
        numpy.min(this_data_matrix),
        numpy.max(this_data_matrix)
    ))

    main_data_dict[VARIABLE_NAMES_2D[j]] = (
        (ROW_DIMENSION, COLUMN_DIMENSION),
        this_data_matrix
    )

hrrr_table_xarray = xarray.Dataset(
    data_vars=main_data_dict, coords=coord_dict, attrs=attribute_dict
)
print(hrrr_table_xarray)

hrrr_table_xarray.to_netcdf(
    path=OUTPUT_FILE_NAME, mode='w', format='NETCDF3_64BIT'
)
# Out:
# "/content/wgrib2_install/grib2/wgrib2/wgrib2" "/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2" -s | grep -w "HGT:700 mb" | "/content/wgrib2_install/grib2/wgrib2/wgrib2" -i "/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2" -no_header -text "/tmp/tmp09qfx3k4"
# "/content/wgrib2_install/grib2/wgrib2/wgrib2" "/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2" -s | grep -w "HGT:850 mb" | "/content/wgrib2_install/grib2/wgrib2/wgrib2" -i "/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2" -no_header -text "/tmp/tmp6_w4jr38"
# "/content/wgrib2_install/grib2/wgrib2/wgrib2" "/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2" -s | grep -w "HGT:1000 mb" | "/content/wgrib2_install/grib2/wgrib2/wgrib2" -i "/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2" -no_header -text "/tmp/tmp07chsspl"
# Min and max values for geopotential_height_m_asl = -1.7e+02, 3.2e+03
# "/content/wgrib2_install/grib2/wgrib2/wgrib2" "/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2" -s | grep -w "UGRD:700 mb" | "/content/wgrib2_install/grib2/wgrib2/wgrib2" -i "/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2" -no_header -text "/tmp/tmpcw4l8d5m"
# "/content/wgrib2_install/grib2/wgrib2/wgrib2" "/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2" -s | grep -w "UGRD:850 mb" | "/content/wgrib2_install/grib2/wgrib2/wgrib2" -i "/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2" -no_header -text "/tmp/tmplpdheb9l"
# "/content/wgrib2_install/grib2/wgrib2/wgrib2" "/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2" -s | grep -w "UGRD:1000 mb" | "/content/wgrib2_install/grib2/wgrib2/wgrib2" -i "/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2" -no_header -text "/tmp/tmpi88_brk5"
# Min and max values for zonal_wind_m_s01 = -35, 30
# "/content/wgrib2_install/grib2/wgrib2/wgrib2" "/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2" -s | grep -w "VGRD:700 mb" | "/content/wgrib2_install/grib2/wgrib2/wgrib2" -i "/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2" -no_header -text "/tmp/tmp1pautbgl"
# "/content/wgrib2_install/grib2/wgrib2/wgrib2" "/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2" -s | grep -w "VGRD:850 mb" | "/content/wgrib2_install/grib2/wgrib2/wgrib2" -i "/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2" -no_header -text "/tmp/tmp4wyd2781"
# "/content/wgrib2_install/grib2/wgrib2/wgrib2" "/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2" -s | grep -w "VGRD:1000 mb" | "/content/wgrib2_install/grib2/wgrib2/wgrib2" -i "/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2" -no_header -text "/tmp/tmp8rim_x66"
# Min and max values for meridional_wind_m_s01 = -27, 41
# "/content/wgrib2_install/grib2/wgrib2/wgrib2" "/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2" -s | grep -w "VVEL:700 mb" | "/content/wgrib2_install/grib2/wgrib2/wgrib2" -i "/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2" -no_header -text "/tmp/tmpysuwuizx"
# "/content/wgrib2_install/grib2/wgrib2/wgrib2" "/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2" -s | grep -w "VVEL:850 mb" | "/content/wgrib2_install/grib2/wgrib2/wgrib2" -i "/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2" -no_header -text "/tmp/tmpilpz05i8"
# "/content/wgrib2_install/grib2/wgrib2/wgrib2" "/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2" -s | grep -w "VVEL:1000 mb" | "/content/wgrib2_install/grib2/wgrib2/wgrib2" -i "/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2" -no_header -text "/tmp/tmp5ijbz7pr"
# Min and max values for vertical_velocity_pa_s01 = -17, 16
# "/content/wgrib2_install/grib2/wgrib2/wgrib2" "/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2" -s | grep -w "TMP:700 mb" | "/content/wgrib2_install/grib2/wgrib2/wgrib2" -i "/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2" -no_header -text "/tmp/tmpqjen8z2a"
# "/content/wgrib2_install/grib2/wgrib2/wgrib2" "/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2" -s | grep -w "TMP:850 mb" | "/content/wgrib2_install/grib2/wgrib2/wgrib2" -i "/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2" -no_header -text "/tmp/tmp1r62c_my"
# "/content/wgrib2_install/grib2/wgrib2/wgrib2" "/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2" -s | grep -w "TMP:1000 mb" | "/content/wgrib2_install/grib2/wgrib2/wgrib2" -i "/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2" -no_header -text "/tmp/tmpllx1y2zg"
# Min and max values for temperature_kelvins = 2.7e+02, 3.2e+02
# "/content/wgrib2_install/grib2/wgrib2/wgrib2" "/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2" -s | grep -w "SPFH:700 mb" | "/content/wgrib2_install/grib2/wgrib2/wgrib2" -i "/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2" -no_header -text "/tmp/tmpga80e6wq"
# "/content/wgrib2_install/grib2/wgrib2/wgrib2" "/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2" -s | grep -w "SPFH:850 mb" | "/content/wgrib2_install/grib2/wgrib2/wgrib2" -i "/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2" -no_header -text "/tmp/tmpihgnh3jx"
# "/content/wgrib2_install/grib2/wgrib2/wgrib2" "/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2" -s | grep -w "SPFH:1000 mb" | "/content/wgrib2_install/grib2/wgrib2/wgrib2" -i "/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2" -no_header -text "/tmp/tmp25q7amv1"
# Min and max values for specific_humidity_kg_kg01 = 0, 0.027
# "/content/wgrib2_install/grib2/wgrib2/wgrib2" "/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2" -s | grep -w "HPBL" | "/content/wgrib2_install/grib2/wgrib2/wgrib2" -i "/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2" -no_header -text "/tmp/tmpgs00l8v0"
# Min and max values for boundary_layer_height_m_asl = 18, 7.5e+03
# "/content/wgrib2_install/grib2/wgrib2/wgrib2" "/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2" -s | grep -w "MASSDEN" | "/content/wgrib2_install/grib2/wgrib2/wgrib2" -i "/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2" -no_header -text "/tmp/tmpa_hxbggn"
# Min and max values for smoke_density_8magl_micrograms_m03 = 9.1e-20, 4.9
# "/content/wgrib2_install/grib2/wgrib2/wgrib2" "/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2" -s | grep -w "COLMD" | "/content/wgrib2_install/grib2/wgrib2/wgrib2" -i "/content/hrrr_data_for_notebook/hrrr.t21z.wrfprsf03.grib2" -no_header -text "/tmp/tmpblzik37t"
# Min and max values for smoke_density_total_column_micrograms_m03 = 0, 5.1e+03
# <xarray.Dataset>
# Dimensions:                                    (row: 1059, column: 1799, pressure_mb: 3)
# Coordinates:
#   * row                                        (row) int64 0 1 2 ... 1057 1058
#   * column                                     (column) int64 0 1 ... 1797 1798
#   * pressure_mb                                (pressure_mb) int64 700 850 1000
# Data variables:
#     latitude_deg_n                             (row, column) float64 21.14 .....
#     longitude_deg_e                            (row, column) float64 -122.7 ....
#     geopotential_height_m_asl                  (row, column, pressure_mb) float64 ...
#     zonal_wind_m_s01                           (row, column, pressure_mb) float64 ...
#     meridional_wind_m_s01                      (row, column, pressure_mb) float64 ...
#     vertical_velocity_pa_s01                   (row, column, pressure_mb) float64 ...
#     temperature_kelvins                        (row, column, pressure_mb) float64 ...
#     specific_humidity_kg_kg01                  (row, column, pressure_mb) float64 ...
#     boundary_layer_height_m_asl                (row, column) float64 610.8 .....
#     smoke_density_8magl_micrograms_m03         (row, column) float64 9.112e-2...
#     smoke_density_total_column_micrograms_m03  (row, column) float64 0.0 ... 0.0
# Attributes:
#     forecast_time_unix_sec:  1662584400
#     valid_time_unix_sec:     1662595200
